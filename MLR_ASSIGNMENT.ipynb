# %% [markdown]
# #### MULTIPLE LINEAR REGRESSION

# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize']=(10,5)
plt.rcParams['figure.dpi']=250
import warnings
warnings.filterwarnings('ignore')

# %%
#read the data
df=pd.read_csv(r'C:\Users\sanket\Desktop\DS ASSIGNMENT\MLR\MLR\ToyotaCorolla.csv')
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %% [markdown]
# #### 1. Perform exploratory data analysis (EDA)

# %% [markdown]
# Encoding Categorical Variables: use one-hot encoding for the Fuel_Type variable

# %%
# One-hot encoding the Fuel_Type variable
df=pd.get_dummies(data=df, columns=['Fuel_Type'],drop_first=True).astype(int)
df
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0     13500         23  46986   90          0  2000      3          4      5
# 1     13750         23  72937   90          0  2000      3          4      5
# 2     13950         24  41711   90          0  2000      3          4      5
# 3     14950         26  48000   90          0  2000      3          4      5
# 4     13750         30  38500   90          0  2000      3          4      5
# ...     ...        ...    ...  ...        ...   ...    ...        ...    ...
# 1431   7500         69  20544   86          0  1300      3          4      5
# 1432  10845         72  19000   86          0  1300      3          4      5
# 1433   8500         71  17016   86          0  1300      3          4      5
# 1434   7250         70  16916   86          0  1300      3          4      5
# 1435   6950         76      1  110          0  1600      5          4      5
#
# ...

# %%
df.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight  \
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             1436 non-null   int32
#  1   Age_08_04         1436 non-null   int32
#  2   KM                1436 non-null   int32
#  3   HP                1436 non-null   int32
#  4   Automatic         1436 non-null   int32
#  5   cc                1436 non-null   int32
#  6   Doors             1436 non-null   int32
#  7   Cylinders         1436 non-null   int32
#  8   Gears             1436 non-null   int32
#  9   Weight            1436 non-null   int32
#  10  Fuel_Type_Diesel  1436 non-null   int32
#  11  Fuel_Type_Petrol  1436 non-null   int32
# dtypes: int32(12)
# memory usage: 67.4 KB

# %%
df.dtypes
# Out:
# Price               int32
# Age_08_04           int32
# KM                  int32
# HP                  int32
# Automatic           int32
# cc                  int32
# Doors               int32
# Cylinders           int32
# Gears               int32
# Weight              int32
# Fuel_Type_Diesel    int32
# Fuel_Type_Petrol    int32
# dtype: object

# %%
#Find duplicate value

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1431    False
# 1432    False
# 1433    False
# 1434    False
# 1435    False
# Length: 1436, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.shape
# Out:
# (1436, 12)

# %%
#remove duplicates

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (1435, 12)

# %%
# find null values

# %%
df.isna()
# Out:
#       Price  Age_08_04     KM     HP  Automatic     cc  Doors  Cylinders  \
# 0     False      False  False  False      False  False  False      False
# 1     False      False  False  False      False  False  False      False
# 2     False      False  False  False      False  False  False      False
# 3     False      False  False  False      False  False  False      False
# 4     False      False  False  False      False  False  False      False
# ...     ...        ...    ...    ...        ...    ...    ...        ...
# 1431  False      False  False  False      False  False  False      False
# 1432  False      False  False  False      False  False  False      False
# 1433  False      False  False  False      False  False  False      False
# 1434  False      False  False  False      False  False  False      False
# 1435  False      False  False  False      False  False  False      False
#
#       Gears  Weight  Fuel_Type_Diesel  Fuel_Type_Petrol
# ...

# %%
df.isna().sum()
# Out:
# Price               0
# Age_08_04           0
# KM                  0
# HP                  0
# Automatic           0
# cc                  0
# Doors               0
# Cylinders           0
# Gears               0
# Weight              0
# Fuel_Type_Diesel    0
# Fuel_Type_Petrol    0
# dtype: int64

# %% [markdown]
# There is no null values in dataset

# %% [markdown]
# #### 2.Statistical Summary

# %%
df
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0     13500         23  46986   90          0  2000      3          4      5
# 1     13750         23  72937   90          0  2000      3          4      5
# 2     13950         24  41711   90          0  2000      3          4      5
# 3     14950         26  48000   90          0  2000      3          4      5
# 4     13750         30  38500   90          0  2000      3          4      5
# ...     ...        ...    ...  ...        ...   ...    ...        ...    ...
# 1431   7500         69  20544   86          0  1300      3          4      5
# 1432  10845         72  19000   86          0  1300      3          4      5
# 1433   8500         71  17016   86          0  1300      3          4      5
# 1434   7250         70  16916   86          0  1300      3          4      5
# 1435   6950         76      1  110          0  1600      5          4      5
#
# ...

# %%
df.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1435.000000  1435.000000    1435.000000  1435.000000  1435.000000
# mean   10720.915679    55.980488   68571.782578   101.491986     0.055749
# std     3608.732978    18.563312   37491.094553    14.981408     0.229517
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63451.000000   110.000000     0.000000
# 75%    11950.000000    70.000000   87041.500000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                  cc        Doors  Cylinders        Gears       Weight  \
# count   1435.000000  1435.000000     1435.0  1435.000000  1435.000000
# mean    1576.560976     4.032753        4.0     5.026481  1072.287108
# std      424.387533     0.952667        0.0     0.188575    52.251882
# ...

# %%
#To find mean

# %%
df.mean()
# Out:
# Price               10720.915679
# Age_08_04              55.980488
# KM                  68571.782578
# HP                    101.491986
# Automatic               0.055749
# cc                   1576.560976
# Doors                   4.032753
# Cylinders               4.000000
# Gears                   5.026481
# Weight               1072.287108
# Fuel_Type_Diesel        0.107317
# Fuel_Type_Petrol        0.880836
# dtype: float64

# %%
#To find median

# %%
df.median()
# Out:
# Price                9900.0
# Age_08_04              61.0
# KM                  63451.0
# HP                    110.0
# Automatic               0.0
# cc                   1600.0
# Doors                   4.0
# Cylinders               4.0
# Gears                   5.0
# Weight               1070.0
# Fuel_Type_Diesel        0.0
# Fuel_Type_Petrol        1.0
# dtype: float64

# %%
# To find standard deviation

# %%
df.std()
# Out:
# Price                3608.732978
# Age_08_04              18.563312
# KM                  37491.094553
# HP                     14.981408
# Automatic               0.229517
# cc                    424.387533
# Doors                   0.952667
# Cylinders               0.000000
# Gears                   0.188575
# Weight                 52.251882
# Fuel_Type_Diesel        0.309624
# Fuel_Type_Petrol        0.324094
# dtype: float64

# %% [markdown]
# #### 3. Data visualization

# %%
sns.pairplot(df)

# %% [markdown]
# #### 4.Scaling the data

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
#Standardization
sc = StandardScaler()

# %%
df.head()
# Out:
#    Price  Age_08_04     KM  HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0  13500         23  46986  90          0  2000      3          4      5
# 1  13750         23  72937  90          0  2000      3          4      5
# 2  13950         24  41711  90          0  2000      3          4      5
# 3  14950         26  48000  90          0  2000      3          4      5
# 4  13750         30  38500  90          0  2000      3          4      5
#
#    Weight  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0    1165                 1                 0
# 1    1165                 1                 0
# 2    1165                 1                 0
# 3    1165                 1                 0
# 4    1170                 1                 0

# %%
x = sc.fit_transform(df)
x
# Out:
# array([[ 0.77036821, -1.77726827, -0.57595832, ...,  1.77496405,
#          2.88412583, -2.71878886],
#        [ 0.83966875, -1.77726827,  0.11647404, ...,  1.77496405,
#          2.88412583, -2.71878886],
#        [ 0.89510918, -1.72337979, -0.71670745, ...,  1.77496405,
#          2.88412583, -2.71878886],
#        ...,
#        [-0.61564265,  0.80937864, -1.37562683, ..., -1.09674669,
#         -0.34672551,  0.36781083],
#        [-0.96214536,  0.75549016, -1.37829506, ..., -1.09674669,
#         -0.34672551,  0.36781083],
#        [-1.04530601,  1.07882103, -1.82962616, ...,  0.7985824 ,
#         -0.34672551,  0.36781083]])

# %%
scaled_data = pd.DataFrame(x, columns=df.columns)
scaled_data
# Out:
#          Price  Age_08_04        KM        HP  Automatic        cc     Doors  \
# 0     0.770368  -1.777268 -0.575958 -0.767351  -0.242983  0.998113 -1.084443
# 1     0.839669  -1.777268  0.116474 -0.767351  -0.242983  0.998113 -1.084443
# 2     0.895109  -1.723380 -0.716707 -0.767351  -0.242983  0.998113 -1.084443
# 3     1.172311  -1.615603 -0.548902 -0.767351  -0.242983  0.998113 -1.084443
# 4     0.839669  -1.400049 -0.802384 -0.767351  -0.242983  0.998113 -1.084443
# ...        ...        ...       ...       ...        ...       ...       ...
# 1430 -0.892845   0.701602 -1.281492 -1.034441  -0.242983 -0.651898 -1.084443
# 1431  0.034396   0.863267 -1.322689 -1.034441  -0.242983 -0.651898 -1.084443
# 1432 -0.615643   0.809379 -1.375627 -1.034441  -0.242983 -0.651898 -1.084443
# 1433 -0.962145   0.755490 -1.378295 -1.034441  -0.242983 -0.651898 -1.084443
# 1434 -1.045306   1.078821 -1.829626  0.568103  -0.242983  0.055249  1.015659
#
# ...

# %%
scaled_data.describe()
# Out:
#               Price     Age_08_04            KM            HP     Automatic  \
# count  1.435000e+03  1.435000e+03  1.435000e+03  1.435000e+03  1.435000e+03
# mean  -3.961214e-17 -2.376728e-16  1.188364e-16 -1.237879e-16 -1.980607e-17
# std    1.000349e+00  1.000349e+00  1.000349e+00  1.000349e+00  1.000349e+00
# min   -1.766032e+00 -2.962815e+00 -1.829626e+00 -2.169577e+00 -2.429827e-01
# 25%   -6.295028e-01 -6.456102e-01 -6.823140e-01 -7.673506e-01 -2.429827e-01
# 50%   -2.275596e-01  2.704939e-01 -1.366343e-01  5.681028e-01 -2.429827e-01
# 75%    3.407048e-01  7.554902e-01  4.928145e-01  5.681028e-01 -2.429827e-01
# max    6.037209e+00  1.294375e+00  4.654146e+00  6.043462e+00  4.115519e+00
#
#                  cc         Doors  Cylinders         Gears        Weight  \
# count  1.435000e+03  1.435000e+03     1435.0  1.435000e+03  1.435000e+03
# mean   1.386425e-16  2.277698e-16        0.0 -2.155148e-15 -5.941821e-16
# ...

# %%
#MinMaxScalar

# %%
mn = MinMaxScaler()

# %%
df
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0     13500         23  46986   90          0  2000      3          4      5
# 1     13750         23  72937   90          0  2000      3          4      5
# 2     13950         24  41711   90          0  2000      3          4      5
# 3     14950         26  48000   90          0  2000      3          4      5
# 4     13750         30  38500   90          0  2000      3          4      5
# ...     ...        ...    ...  ...        ...   ...    ...        ...    ...
# 1431   7500         69  20544   86          0  1300      3          4      5
# 1432  10845         72  19000   86          0  1300      3          4      5
# 1433   8500         71  17016   86          0  1300      3          4      5
# 1434   7250         70  16916   86          0  1300      3          4      5
# 1435   6950         76      1  110          0  1600      5          4      5
#
# ...

# %%
minmax_scaled = pd.DataFrame(mn.fit_transform(df), columns=df.columns)
minmax_scaled
# Out:
#          Price  Age_08_04        KM        HP  Automatic        cc     Doors  \
# 0     0.325044   0.278481  0.193355  0.170732        0.0  0.047619  0.333333
# 1     0.333925   0.278481  0.300149  0.170732        0.0  0.047619  0.333333
# 2     0.341030   0.291139  0.171647  0.170732        0.0  0.047619  0.333333
# 3     0.376554   0.316456  0.197528  0.170732        0.0  0.047619  0.333333
# 4     0.333925   0.367089  0.158433  0.170732        0.0  0.047619  0.333333
# ...        ...        ...       ...       ...        ...       ...       ...
# 1430  0.111901   0.860759  0.084539  0.138211        0.0  0.000000  0.333333
# 1431  0.230728   0.898734  0.078186  0.138211        0.0  0.000000  0.333333
# 1432  0.147425   0.886076  0.070021  0.138211        0.0  0.000000  0.333333
# 1433  0.103020   0.873418  0.069609  0.138211        0.0  0.000000  0.333333
# 1434  0.092362   0.949367  0.000000  0.333333        0.0  0.020408  1.000000
#
# ...

# %%
minmax_scaled.describe()
# Out:
#              Price    Age_08_04           KM           HP    Automatic  \
# count  1435.000000  1435.000000  1435.000000  1435.000000  1435.000000
# mean      0.226320     0.695956     0.282185     0.264162     0.055749
# std       0.128197     0.234979     0.154285     0.121800     0.229517
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.145648     0.544304     0.176951     0.170732     0.000000
# 50%       0.197158     0.759494     0.261112     0.333333     0.000000
# 75%       0.269982     0.873418     0.358193     0.333333     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears       Weight  \
# count  1435.000000  1435.000000     1435.0  1435.000000  1435.000000
# mean      0.018814     0.677584        0.0     0.675494     0.117540
# std       0.028870     0.317556        0.0     0.062858     0.084962
# ...

# %% [markdown]
# #### 5.Check for multicollinearity

# %% [markdown]
# Use variance inflation factor (VIF) to detect multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
scaled_data
# Out:
#          Price  Age_08_04        KM        HP  Automatic        cc     Doors  \
# 0     0.770368  -1.777268 -0.575958 -0.767351  -0.242983  0.998113 -1.084443
# 1     0.839669  -1.777268  0.116474 -0.767351  -0.242983  0.998113 -1.084443
# 2     0.895109  -1.723380 -0.716707 -0.767351  -0.242983  0.998113 -1.084443
# 3     1.172311  -1.615603 -0.548902 -0.767351  -0.242983  0.998113 -1.084443
# 4     0.839669  -1.400049 -0.802384 -0.767351  -0.242983  0.998113 -1.084443
# ...        ...        ...       ...       ...        ...       ...       ...
# 1430 -0.892845   0.701602 -1.281492 -1.034441  -0.242983 -0.651898 -1.084443
# 1431  0.034396   0.863267 -1.322689 -1.034441  -0.242983 -0.651898 -1.084443
# 1432 -0.615643   0.809379 -1.375627 -1.034441  -0.242983 -0.651898 -1.084443
# 1433 -0.962145   0.755490 -1.378295 -1.034441  -0.242983 -0.651898 -1.084443
# 1434 -1.045306   1.078821 -1.829626  0.568103  -0.242983  0.055249  1.015659
#
# ...

# %%
data = scaled_data.drop(columns=['Price'])
data
# Out:
#       Age_08_04        KM        HP  Automatic        cc     Doors  Cylinders  \
# 0     -1.777268 -0.575958 -0.767351  -0.242983  0.998113 -1.084443        0.0
# 1     -1.777268  0.116474 -0.767351  -0.242983  0.998113 -1.084443        0.0
# 2     -1.723380 -0.716707 -0.767351  -0.242983  0.998113 -1.084443        0.0
# 3     -1.615603 -0.548902 -0.767351  -0.242983  0.998113 -1.084443        0.0
# 4     -1.400049 -0.802384 -0.767351  -0.242983  0.998113 -1.084443        0.0
# ...         ...       ...       ...        ...       ...       ...        ...
# 1430   0.701602 -1.281492 -1.034441  -0.242983 -0.651898 -1.084443        0.0
# 1431   0.863267 -1.322689 -1.034441  -0.242983 -0.651898 -1.084443        0.0
# 1432   0.809379 -1.375627 -1.034441  -0.242983 -0.651898 -1.084443        0.0
# 1433   0.755490 -1.378295 -1.034441  -0.242983 -0.651898 -1.084443        0.0
# 1434   1.078821 -1.829626  0.568103  -0.242983  0.055249  1.015659        0.0
#
# ...

# %%
data.values
# Out:
# array([[-1.77726827, -0.57595832, -0.76735061, ...,  1.77496405,
#          2.88412583, -2.71878886],
#        [-1.77726827,  0.11647404, -0.76735061, ...,  1.77496405,
#          2.88412583, -2.71878886],
#        [-1.72337979, -0.71670745, -0.76735061, ...,  1.77496405,
#          2.88412583, -2.71878886],
#        ...,
#        [ 0.80937864, -1.37562683, -1.03444129, ..., -1.09674669,
#         -0.34672551,  0.36781083],
#        [ 0.75549016, -1.37829506, -1.03444129, ..., -1.09674669,
#         -0.34672551,  0.36781083],
#        [ 1.07882103, -1.82962616,  0.56810282, ...,  0.7985824 ,
#         -0.34672551,  0.36781083]])

# %%
vif = pd.DataFrame()
vif
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data.columns
# Out:
# Index(['Age_08_04', 'KM', 'HP', 'Automatic', 'cc', 'Doors', 'Cylinders',
#        'Gears', 'Weight', 'Fuel_Type_Diesel', 'Fuel_Type_Petrol'],
#       dtype='object')

# %%
vif['Features'] = data.columns
vif
# Out:
#             Features
# 0          Age_08_04
# 1                 KM
# 2                 HP
# 3          Automatic
# 4                 cc
# 5              Doors
# 6          Cylinders
# 7              Gears
# 8             Weight
# 9   Fuel_Type_Diesel
# 10  Fuel_Type_Petrol

# %%
range(len(data.columns))
# Out:
# range(0, 11)

# %%
[variance_inflation_factor(data,i) for i in range(0,11)]
# Out:
# [1.9119519389147475,
#  2.002649407883752,
#  2.3006921398529423,
#  1.0946187113590002,
#  1.2236058256151423,
#  1.217072020634191,
#  nan,
#  1.117553987278675,
#  3.254341823279579,
#  11.25876192536974,
#  9.652517660082673]

# %%
vif['VIF'] = [variance_inflation_factor(data.values,i) for i in range(len(data.columns))]

# %%
vif
# Out:
#             Features        VIF
# 0          Age_08_04   1.911952
# 1                 KM   2.002649
# 2                 HP   2.300692
# 3          Automatic   1.094619
# 4                 cc   1.223606
# 5              Doors   1.217072
# 6          Cylinders        NaN
# 7              Gears   1.117554
# 8             Weight   3.254342
# 9   Fuel_Type_Diesel  11.258762
# 10  Fuel_Type_Petrol   9.652518

# %%
scaled_data.drop(columns=['Cylinders','Fuel_Type_Diesel','Fuel_Type_Petrol'])

# %%
scaled_data
# Out:
#          Price  Age_08_04        KM        HP  Automatic        cc     Doors  \
# 0     0.770368  -1.777268 -0.575958 -0.767351  -0.242983  0.998113 -1.084443
# 1     0.839669  -1.777268  0.116474 -0.767351  -0.242983  0.998113 -1.084443
# 2     0.895109  -1.723380 -0.716707 -0.767351  -0.242983  0.998113 -1.084443
# 3     1.172311  -1.615603 -0.548902 -0.767351  -0.242983  0.998113 -1.084443
# 4     0.839669  -1.400049 -0.802384 -0.767351  -0.242983  0.998113 -1.084443
# ...        ...        ...       ...       ...        ...       ...       ...
# 1430 -0.892845   0.701602 -1.281492 -1.034441  -0.242983 -0.651898 -1.084443
# 1431  0.034396   0.863267 -1.322689 -1.034441  -0.242983 -0.651898 -1.084443
# 1432 -0.615643   0.809379 -1.375627 -1.034441  -0.242983 -0.651898 -1.084443
# 1433 -0.962145   0.755490 -1.378295 -1.034441  -0.242983 -0.651898 -1.084443
# 1434 -1.045306   1.078821 -1.829626  0.568103  -0.242983  0.055249  1.015659
#
#          Gears    Weight
# ...

# %% [markdown]
# #### 6. Split the data into Training and Testing sets

# %%
scaled_data.head()
# Out:
#       Price  Age_08_04        KM        HP  Automatic        cc     Doors  \
# 0  0.770368  -1.777268 -0.575958 -0.767351  -0.242983  0.998113 -1.084443
# 1  0.839669  -1.777268  0.116474 -0.767351  -0.242983  0.998113 -1.084443
# 2  0.895109  -1.723380 -0.716707 -0.767351  -0.242983  0.998113 -1.084443
# 3  1.172311  -1.615603 -0.548902 -0.767351  -0.242983  0.998113 -1.084443
# 4  0.839669  -1.400049 -0.802384 -0.767351  -0.242983  0.998113 -1.084443
#
#       Gears    Weight
# 0 -0.140475  1.774964
# 1 -0.140475  1.774964
# 2 -0.140475  1.774964
# 3 -0.140475  1.774964
# 4 -0.140475  1.870688

# %%
x = scaled_data.iloc[:,1:]
y = scaled_data['Price']

# %%
x
# Out:
#       Age_08_04        KM        HP  Automatic        cc     Doors     Gears  \
# 0     -1.777268 -0.575958 -0.767351  -0.242983  0.998113 -1.084443 -0.140475
# 1     -1.777268  0.116474 -0.767351  -0.242983  0.998113 -1.084443 -0.140475
# 2     -1.723380 -0.716707 -0.767351  -0.242983  0.998113 -1.084443 -0.140475
# 3     -1.615603 -0.548902 -0.767351  -0.242983  0.998113 -1.084443 -0.140475
# 4     -1.400049 -0.802384 -0.767351  -0.242983  0.998113 -1.084443 -0.140475
# ...         ...       ...       ...        ...       ...       ...       ...
# 1430   0.701602 -1.281492 -1.034441  -0.242983 -0.651898 -1.084443 -0.140475
# 1431   0.863267 -1.322689 -1.034441  -0.242983 -0.651898 -1.084443 -0.140475
# 1432   0.809379 -1.375627 -1.034441  -0.242983 -0.651898 -1.084443 -0.140475
# 1433   0.755490 -1.378295 -1.034441  -0.242983 -0.651898 -1.084443 -0.140475
# 1434   1.078821 -1.829626  0.568103  -0.242983  0.055249  1.015659 -0.140475
#
#         Weight
# 0     1.774964
# ...

# %%
y
# Out:
# 0       0.770368
# 1       0.839669
# 2       0.895109
# 3       1.172311
# 4       0.839669
#           ...
# 1430   -0.892845
# 1431    0.034396
# 1432   -0.615643
# 1433   -0.962145
# 1434   -1.045306
# Name: Price, Length: 1435, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split(x,y,train_size=0.8)
# Out:
# [      Age_08_04        KM        HP  Automatic        cc     Doors     Gears  \
#  497    0.001051 -0.278291  0.568103  -0.242983  0.055249  1.015659 -0.140475
#  435   -0.483945  0.272512  0.568103  -0.242983  0.055249  1.015659 -0.140475
#  241   -0.699499 -0.274688  0.568103  -0.242983  0.055249 -1.084443 -0.140475
#  1131   0.971044  1.005341  0.568103  -0.242983  0.055249  1.015659 -0.140475
#  1330   1.024933 -0.095143 -1.034441  -0.242983 -0.651898 -1.084443 -0.140475
#  ...         ...       ...       ...        ...       ...       ...       ...
#  259   -0.807276 -0.449324 -0.299942  -0.242983 -0.416182 -1.084443 -0.140475
#  1360   0.809379 -0.251021  0.568103  -0.242983  0.055249 -0.034392 -0.140475
#  1317   1.186598 -0.035135  0.568103  -0.242983  0.055249  1.015659 -0.140475
#  720    0.324382  0.536187  0.568103  -0.242983  0.055249 -0.034392 -0.140475
#  277   -0.699499 -0.588526 -0.299942  -0.242983 -0.416182  1.015659 -0.140475
#
#          Weight
# ...

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
xtrain
# Out:
#       Age_08_04        KM        HP  Automatic        cc     Doors     Gears  \
# 1127   1.186598  1.085735  0.568103  -0.242983  0.055249  1.015659 -0.140475
# 898    0.324382 -0.247526 -1.034441  -0.242983 -0.651898  1.015659 -0.140475
# 1187   0.809379  0.581627 -1.034441  -0.242983 -0.651898  1.015659 -0.140475
# 310   -0.645610 -0.803425  0.568103  -0.242983  0.055249  1.015659 -0.140475
# 1144   1.024933  0.888073  0.568103  -0.242983  0.055249  1.015659 -0.140475
# ...         ...       ...       ...        ...       ...       ...       ...
# 1095   1.024933  1.516308  0.568103  -0.242983  0.055249 -1.084443 -0.140475
# 1130   1.024933  1.025353  0.568103  -0.242983  0.055249 -1.084443 -0.140475
# 1294   1.294375  0.078132  0.568103  -0.242983  0.055249 -0.034392 -0.140475
# 860    0.486048 -0.105176  0.568103  -0.242983  0.055249  1.015659 -0.140475
# 1126   1.024933  1.093126  0.568103  -0.242983  0.055249  1.015659 -0.140475
#
#         Weight
# 1127 -0.043786
# ...

# %%
ytrain
# Out:
# 1127   -0.892845
# 898    -0.338440
# 1187   -0.768104
# 310     0.907583
# 1144   -1.183907
#           ...
# 1095   -0.781964
# 1130   -0.213699
# 1294   -0.892845
# 860     0.063503
# 1126   -0.560202
# Name: Price, Length: 1148, dtype: float64

# %%
xtest
# Out:
#       Age_08_04        KM        HP  Automatic        cc     Doors     Gears  \
# 752    0.162717  0.316405  0.568103  -0.242983  0.055249 -1.084443  5.164307
# 857    0.324382 -0.100720  0.568103  -0.242983  0.055249  1.015659 -0.140475
# 629    0.162717  1.639046 -1.969259  -0.242983  0.998113 -0.034392 -0.140475
# 1411   0.701602 -0.687650  0.568103  -0.242983  0.055249 -1.084443 -0.140475
# 974    0.486048 -0.575211 -1.034441  -0.242983 -0.651898 -1.084443 -0.140475
# ...         ...       ...       ...        ...       ...       ...       ...
# 1112   0.917156  1.262212  0.568103  -0.242983  0.055249 -0.034392 -0.140475
# 174   -2.585595 -1.600879  0.568103  -0.242983  0.055249  1.015659 -0.140475
# 1427   0.863267 -1.135913 -1.034441  -0.242983 -0.651898 -1.084443 -0.140475
# 297   -1.130607 -0.735679  0.568103  -0.242983  0.055249  1.015659 -0.140475
# 1125   1.294375  1.105400  0.568103  -0.242983  0.055249 -0.034392 -0.140475
#
#         Weight
# 752  -0.139510
# ...

# %%
ytest
# Out:
# 752    -0.213699
# 857    -0.755630
# 629    -0.892845
# 1411   -0.213699
# 974    -0.490902
#           ...
# 1112   -1.377949
# 174     2.558322
# 1427   -0.629503
# 297     0.907583
# 1125   -1.086886
# Name: Price, Length: 287, dtype: float64

# %% [markdown]
# #### 7.Building Multiple Linear Regression Models

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
# Model 1: Basic MLR Model

# %%
model_1 = LinearRegression()
model_1.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
# Model 2: MLR Model with StatsModels for detailed summary

# %%
xtrain_sm = sm.add_constant(xtrain)  # Adding a constant for the intercept
model_2 = sm.OLS(ytrain,xtrain_sm).fit()

# %%
model_2

# %%
# Model 3: Removing highly correlated features (example: Removing 'Age_08_04')

# %%
#xtrain_reduced = xtrain[:, [i for i in range(xtrain.shape[0]) if i != 0]]  # Removing the second feature as an example
#xtest_reduced = xtest[:, [i for i in range(xtest.shape[0]) if i != 0]]
#model_3 = LinearRegression()
#model_3.fit(xtrain_reduced, ytrain)

# %% [markdown]
# #### 8.Evaluating Model Performance

# %% [markdown]
# evaluate the models using metrics like Mean Absolute Error (MAE), Mean Squared Error (MSE), and R-squared (R²).

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
y_pred_1 = model_1.predict(xtest)

# %%
y_pred_1
# Out:
# array([-1.72109894e-02, -1.11436897e-01, -3.63872982e-01, -3.54822946e-01,
#        -6.30827625e-01, -6.61676148e-01, -7.30803393e-01, -6.69042960e-01,
#         2.97647974e-01,  4.76852791e-01, -3.84633494e-01, -3.80408707e-01,
#         6.90549473e-01,  4.48028140e-01, -4.79944187e-01,  2.33709876e-01,
#         4.45345388e-01,  1.85889821e+00,  2.64651179e-01,  2.33876531e-01,
#         2.46358849e-01,  2.01601225e+00, -2.38934329e-01, -7.12117866e-02,
#        -9.50436825e-01,  1.45164603e+00, -1.01211989e+00, -6.30080023e-01,
#         1.31837615e+00,  8.75831586e-01, -7.19480782e-01,  2.23048909e-02,
#        -1.72890320e-01, -1.66653802e-01, -1.66942603e-01, -6.01575619e-01,
#        -5.11827703e-01, -2.04329513e-01,  1.51400950e+00, -3.46674138e-03,
#        -5.87704447e-01, -3.25418745e-01, -1.65373365e-01, -6.14478461e-01,
#        -3.11983523e-02,  1.86644887e+00, -5.22966852e-02, -3.91290991e-01,
# ...

# %%
def evaluate_model(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    return mae, mse, r2

# %%
MAE,MSE,R2= evaluate_model(ytest, y_pred_1)

# %%
MAE
# Out:
# 0.2743547700109547

# %%
MSE
# Out:
# 0.14799929411256474

# %%
R2
# Out:
# 0.8394579184382986

# %% [markdown]
# #### 9.Applying Lasso and Ridge Methods

# %% [markdown]
#  Apply Lasso and Ridge regularization techniques to the model and evaluate their performance.

# %%
from sklearn.linear_model import Lasso, Ridge

# %%
# Lasso
lasso = Lasso(alpha=1.0)
lasso.fit(xtrain, ytrain)
y_pred_lasso = lasso.predict(xtest)

# %%
y_pred_lasso
# Out:
# array([0.00169938, 0.00169938, 0.00169938, 0.00169938, 0.00169938,
#        0.00169938, 0.00169938, 0.00169938, 0.00169938, 0.00169938,
#        0.00169938, 0.00169938, 0.00169938, 0.00169938, 0.00169938,
#        0.00169938, 0.00169938, 0.00169938, 0.00169938, 0.00169938,
#        0.00169938, 0.00169938, 0.00169938, 0.00169938, 0.00169938,
#        0.00169938, 0.00169938, 0.00169938, 0.00169938, 0.00169938,
#        0.00169938, 0.00169938, 0.00169938, 0.00169938, 0.00169938,
#        0.00169938, 0.00169938, 0.00169938, 0.00169938, 0.00169938,
#        0.00169938, 0.00169938, 0.00169938, 0.00169938, 0.00169938,
#        0.00169938, 0.00169938, 0.00169938, 0.00169938, 0.00169938,
#        0.00169938, 0.00169938, 0.00169938, 0.00169938, 0.00169938,
#        0.00169938, 0.00169938, 0.00169938, 0.00169938, 0.00169938,
#        0.00169938, 0.00169938, 0.00169938, 0.00169938, 0.00169938,
#        0.00169938, 0.00169938, 0.00169938, 0.00169938, 0.00169938,
# ...

# %%
# Ridge
ridge = Ridge(alpha=1.0)
ridge.fit(xtrain, ytrain)
y_pred_ridge = ridge.predict(xtest)

# %%
y_pred_ridge
# Out:
# array([-1.72320350e-02, -1.11146623e-01, -3.63808564e-01, -3.54359456e-01,
#        -6.30433168e-01, -6.61171287e-01, -7.30124729e-01, -6.68412854e-01,
#         2.97142068e-01,  4.76317930e-01, -3.84285515e-01, -3.80063333e-01,
#         6.90205816e-01,  4.47665568e-01, -4.79139515e-01,  2.33748947e-01,
#         4.45186653e-01,  1.85780752e+00,  2.64427436e-01,  2.33709367e-01,
#         2.46133854e-01,  2.01488178e+00, -2.38299466e-01, -7.12036308e-02,
#        -9.49992595e-01,  1.45101163e+00, -1.01126834e+00, -6.29953287e-01,
#         1.31771272e+00,  8.75583105e-01, -7.19098512e-01,  2.27691138e-02,
#        -1.72631478e-01, -1.66676834e-01, -1.66566386e-01, -6.01086642e-01,
#        -5.11600474e-01, -2.04321868e-01,  1.51313302e+00, -3.46740835e-03,
#        -5.87674084e-01, -3.25193578e-01, -1.65002931e-01, -6.14129284e-01,
#        -3.08315996e-02,  1.86532936e+00, -5.22607683e-02, -3.90730593e-01,
# ...

# %%
# Evaluating Lasso and Ridge
metrics_lasso = evaluate_model(ytest, y_pred_lasso)
metrics_ridge = evaluate_model(ytest, y_pred_ridge)

# %%
metrics_lasso
# Out:
# (0.7046969987872376, 0.9219444736287586, -7.83163742288373e-05)

# %%
metrics_ridge
# Out:
# (0.27432464054470124, 0.1479708785036561, 0.8394887422407389)
